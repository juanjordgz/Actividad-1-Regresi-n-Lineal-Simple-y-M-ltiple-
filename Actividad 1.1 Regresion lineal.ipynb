# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Datos_Rio_Limpio.csv")
df.head(5)
# Out:
#    Unnamed: 0       source                                               name  \
# 0           0  city scrape  Very Nice 2Br in Copacabana w. balcony, fast WiFi
# 1           1  city scrape    Beautiful Modern Decorated Studio in Copacabana
# 2           2  city scrape    COPACABANA SEA BREEZE  -  RIO - 25  X Superhost
# 3           3  city scrape           Bright 6bed Penthouse Seconds from Beach
# 4           4  city scrape  Extra large 4BD 3BT on the AtlanticAve. Copaca...
#
#                   host_name           host_location host_response_time  \
# 0                  Matthias  Rio de Janeiro, Brazil     within an hour
# 1                   Viviane  Rio de Janeiro, Brazil     within an hour
# 2  Patricia Miranda & Paulo  Rio de Janeiro, Brazil     within an hour
# 3                   Goitaca  Rio de Janeiro, Brazil     within an hour
# 4                    Marcio  Rio de Janeiro, Brazil     within an hour
#
# ...

# %% [markdown]
# df general

# %%
cuantitativas = df.select_dtypes(include=["int64", "float64", "int32", "float32", "int", "float"])
print("Columnas cuantitativas:\n", cuantitativas.columns.tolist())
# Out:
# Columnas cuantitativas:
# ...

# %%
pd.options.display.max_columns = None

# %%
Corr_Factorsdf=cuantitativas.corr()
Corr_Factorsdf
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                           -0.055676                 NaN
# host_is_superhost                              -0.072518                 NaN
# host_listings_count                             0.029648                 NaN
# host_total_listings_count                       0.023566                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.028747                 NaN
# longitude                                       0.047702                 NaN
# accommodates                                   -0.049921                 NaN
# ...

# %%
Corr_factordf= abs(Corr_Factorsdf)
Corr_factordf
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                            0.055676                 NaN
# host_is_superhost                               0.072518                 NaN
# host_listings_count                             0.029648                 NaN
# host_total_listings_count                       0.023566                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.028747                 NaN
# longitude                                       0.047702                 NaN
# accommodates                                    0.049921                 NaN
# ...

# %%
var_dep = "review_scores_rating"


correls = df.corr(numeric_only=True)[var_dep].drop(var_dep)  


correls_abs = correls.abs().sort_values(ascending=False)


print(f"Variables más correlacionadas con {var_dep}:\n")
print(correls_abs.head(5))


print("\nCon signo original:\n")
print(correls.loc[correls_abs.index[:5]])
# Out:
# Variables más correlacionadas con review_scores_rating:
#
# review_scores_accuracy         0.695771
# review_scores_cleanliness      0.644472
# review_scores_value            0.643359
# review_scores_communication    0.529844
# review_scores_checkin          0.489078
# Name: review_scores_rating, dtype: float64
#
# Con signo original:
#
# review_scores_accuracy         0.695771
# review_scores_cleanliness      0.644472
# review_scores_value            0.643359
# review_scores_communication    0.529844
# review_scores_checkin          0.489078
# Name: review_scores_rating, dtype: float64

# %%
df1 = df[df['room_type'] == 'Entire home/apt']
df2 = df[df['room_type'] == 'Private room']
df3 = df[df['room_type'] == 'Shared room']
df4 = df[df['room_type'] == 'Hotel room']

# %% [markdown]
# Entire Home/apt df1

# %%
cuantitativasdf1 = df1.select_dtypes(include=["int64", "float64", "int32", "float32", "int", "float"])
print("Columnas cuantitativas:\n", cuantitativas.columns.tolist())
# Out:
# Columnas cuantitativas:
# ...

# %%
Corr_Factorsdf1=cuantitativasdf1.corr()
Corr_Factorsdf1
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                           -0.044041                 NaN
# host_is_superhost                              -0.061675                 NaN
# host_listings_count                             0.044241                 NaN
# host_total_listings_count                       0.038293                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.031113                 NaN
# longitude                                       0.045370                 NaN
# accommodates                                   -0.063598                 NaN
# ...

# %%
pd.options.display.max_columns = None

# %%
Corr_factordf1= abs(Corr_Factorsdf1)
Corr_factordf1
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                            0.044041                 NaN
# host_is_superhost                               0.061675                 NaN
# host_listings_count                             0.044241                 NaN
# host_total_listings_count                       0.038293                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.031113                 NaN
# longitude                                       0.045370                 NaN
# accommodates                                    0.063598                 NaN
# ...

# %%
pares = [
    ("host_acceptance_rate", "host_response_rate"),
    ("review_scores_rating", "calculated_host_listings_count"),
    ("host_acceptance_rate", "price"),
    ("availability_365", "number_of_reviews"),
    ("host_acceptance_rate", "number_of_reviews"),
    ("reviews_per_month", "review_scores_communication"),
]

for x, y in pares:
    if x in df1.columns and y in df1.columns:
        corr = df1[[x, y]].corr().iloc[0,1]
        print(f"Correlación entre {x} y {y}: {abs(corr):.6f}")
# Out:
# Correlación entre host_acceptance_rate y host_response_rate: nan
# Correlación entre review_scores_rating y calculated_host_listings_count: 0.033248
# Correlación entre host_acceptance_rate y price: 0.064818
# Correlación entre availability_365 y number_of_reviews: 0.132964
# Correlación entre host_acceptance_rate y number_of_reviews: 0.116986
# Correlación entre reviews_per_month y review_scores_communication: 0.075190

# %%
num_df1 = df1.select_dtypes(include=["int64","float64","int32","float32","int","float"])
num_df1 = num_df1.loc[:, ~num_df1.columns.str.contains('^Unnamed')]

corr_df1 = num_df1.corr().abs()

mask = np.triu(np.ones(corr_df1.shape), k=1).astype(bool)
corr_triu_df1 = corr_df1.where(mask)

corr_pairs_df1 = corr_triu_df1.stack().reset_index()
corr_pairs_df1.columns = ["Variable 1", "Variable 2", "Correlación_abs"]

top10_df1 = corr_pairs_df1.sort_values(by="Correlación_abs", ascending=False).head(10)

print("\nTop 10 correlaciones en df1 (Entire home/apt):\n")
display(top10_df1)
# Out:
# Top 10 correlaciones en df1 (Entire home/apt):
#                  Variable 1                 Variable 2  Correlación_abs
# 497  minimum_maximum_nights     maximum_nights_avg_ntm         0.973765
# 610         availability_60            availability_90         0.966237
# 521  maximum_maximum_nights     maximum_nights_avg_ntm         0.961336
# 589         availability_30            availability_60         0.933895
# 687   number_of_reviews_ltm  estimated_occupancy_l365d         0.910892
# 495  minimum_maximum_nights     maximum_maximum_nights         0.906384
# 386          minimum_nights     minimum_minimum_nights         0.879661
# 590         availability_30            availability_90         0.861283
# 652        availability_365           availability_eoy         0.857459
# 390          minimum_nights     minimum_nights_avg_ntm         0.852125

# %% [markdown]
# Private Room df2

# %%
cuantitativasdf2 = df2.select_dtypes(include=["int64", "float64", "int32", "float32", "int", "float"])
print("Columnas cuantitativas:\n", cuantitativas.columns.tolist())
# Out:
# Columnas cuantitativas:
# ...

# %%
Corr_Factorsdf2=cuantitativasdf2.corr()
Corr_Factorsdf2
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                           -0.089540                 NaN
# host_is_superhost                              -0.112627                 NaN
# host_listings_count                            -0.030811                 NaN
# host_total_listings_count                      -0.033020                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.008024                 NaN
# longitude                                       0.049475                 NaN
# accommodates                                    0.022439                 NaN
# ...

# %%
Corr_factordf2= abs(Corr_Factorsdf2)
Corr_factordf2
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                            0.089540                 NaN
# host_is_superhost                               0.112627                 NaN
# host_listings_count                             0.030811                 NaN
# host_total_listings_count                       0.033020                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.008024                 NaN
# longitude                                       0.049475                 NaN
# accommodates                                    0.022439                 NaN
# ...

# %%
pares = [
    ("host_acceptance_rate", "host_response_rate"),
    ("review_scores_rating", "calculated_host_listings_count"),
    ("host_acceptance_rate", "price"),
    ("availability_365", "number_of_reviews"),
    ("host_acceptance_rate", "number_of_reviews"),
    ("reviews_per_month", "review_scores_communication"),
]

for x, y in pares:
    if x in df2.columns and y in df2.columns:
        corr = df2[[x, y]].corr().iloc[0,1]
        print(f"Correlación entre {x} y {y}: {abs(corr):.6f}")
# Out:
# Correlación entre host_acceptance_rate y host_response_rate: nan
# Correlación entre review_scores_rating y calculated_host_listings_count: 0.071178
# Correlación entre host_acceptance_rate y price: 0.051183
# Correlación entre availability_365 y number_of_reviews: 0.116731
# Correlación entre host_acceptance_rate y number_of_reviews: 0.041426
# Correlación entre reviews_per_month y review_scores_communication: 0.093955

# %%
num_df2 = df2.select_dtypes(include=["int64","float64","int32","float32","int","float"])
num_df2 = num_df2.loc[:, ~num_df2.columns.str.contains('^Unnamed')]

corr_df2 = num_df2.corr().abs()

mask = np.triu(np.ones(corr_df2.shape), k=1).astype(bool)
corr_triu_df2 = corr_df2.where(mask)

corr_pairs_df2 = corr_triu_df2.stack().reset_index()
corr_pairs_df2.columns = ["Variable 1", "Variable 2", "Correlación_abs"]

top10_df2 = corr_pairs_df2.sort_values(by="Correlación_abs", ascending=False).head(10)

print("\nTop 10 correlaciones en df2 (Private Room):\n")
display(top10_df2)
# Out:
# Top 10 correlaciones en df2 (Private Room):
#                  Variable 1                 Variable 2  Correlación_abs
# 497  minimum_maximum_nights     maximum_nights_avg_ntm         0.990136
# 521  maximum_maximum_nights     maximum_nights_avg_ntm         0.987811
# 610         availability_60            availability_90         0.981740
# 495  minimum_maximum_nights     maximum_maximum_nights         0.969066
# 589         availability_30            availability_60         0.958613
# 687   number_of_reviews_ltm  estimated_occupancy_l365d         0.940339
# 386          minimum_nights     minimum_minimum_nights         0.931112
# 390          minimum_nights     minimum_nights_avg_ntm         0.923512
# 445  minimum_minimum_nights     minimum_nights_avg_ntm         0.921220
# 590         availability_30            availability_90         0.913264

# %% [markdown]
# Shared Room df3

# %%
cuantitativasdf3 = df3.select_dtypes(include=["int64", "float64", "int32", "float32", "int", "float"])
print("Columnas cuantitativas:\n", cuantitativas.columns.tolist())
# Out:
# Columnas cuantitativas:
# ...

# %%
Corr_Factorsdf3=cuantitativasdf3.corr()
Corr_Factorsdf3
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                           -0.124575                 NaN
# host_is_superhost                              -0.198460                 NaN
# host_listings_count                            -0.215857                 NaN
# host_total_listings_count                      -0.219841                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.026838                 NaN
# longitude                                       0.242922                 NaN
# accommodates                                   -0.011690                 NaN
# ...

# %%
Corr_factordf3= abs(Corr_Factorsdf3)
Corr_factordf3
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                            0.124575                 NaN
# host_is_superhost                               0.198460                 NaN
# host_listings_count                             0.215857                 NaN
# host_total_listings_count                       0.219841                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.026838                 NaN
# longitude                                       0.242922                 NaN
# accommodates                                    0.011690                 NaN
# ...

# %%
pares = [
    ("host_acceptance_rate", "host_response_rate"),
    ("review_scores_rating", "calculated_host_listings_count"),
    ("host_acceptance_rate", "price"),
    ("availability_365", "number_of_reviews"),
    ("host_acceptance_rate", "number_of_reviews"),
    ("reviews_per_month", "review_scores_communication"),
]

for x, y in pares:
    if x in df3.columns and y in df3.columns:
        corr = df3[[x, y]].corr().iloc[0,1]
        print(f"Correlación entre {x} y {y}: {abs(corr):.6f}")
# Out:
# Correlación entre host_acceptance_rate y host_response_rate: nan
# Correlación entre review_scores_rating y calculated_host_listings_count: 0.025735
# Correlación entre host_acceptance_rate y price: 0.110603
# Correlación entre availability_365 y number_of_reviews: 0.039299
# Correlación entre host_acceptance_rate y number_of_reviews: 0.088385
# Correlación entre reviews_per_month y review_scores_communication: 0.061170

# %%
num_df3 = df3.select_dtypes(include=["int64","float64","int32","float32","int","float"])
num_df3 = num_df3.loc[:, ~num_df3.columns.str.contains('^Unnamed')]


corr_df3 = num_df3.corr().abs()

mask = np.triu(np.ones(corr_df3.shape), k=1).astype(bool)
corr_triu_df3 = corr_df3.where(mask)

corr_pairs_df3 = corr_triu_df3.stack().reset_index()
corr_pairs_df3.columns = ["Variable 1", "Variable 2", "Correlación_abs"]

top10_df3 = corr_pairs_df3.sort_values(by="Correlación_abs", ascending=False).head(10)

print("\nTop 10 correlaciones en df3 (Shared Room):\n")
display(top10_df3)
# Out:
# Top 10 correlaciones en df3 (Shared Room):
#                  Variable 1                 Variable 2  Correlación_abs
# 687   number_of_reviews_ltm  estimated_occupancy_l365d         0.995784
# 497  minimum_maximum_nights     maximum_nights_avg_ntm         0.989649
# 445  minimum_minimum_nights     minimum_nights_avg_ntm         0.988160
# 521  maximum_maximum_nights     maximum_nights_avg_ntm         0.983875
# 390          minimum_nights     minimum_nights_avg_ntm         0.978981
# 610         availability_60            availability_90         0.977953
# 386          minimum_nights     minimum_minimum_nights         0.975677
# 495  minimum_maximum_nights     maximum_maximum_nights         0.950028
# 589         availability_30            availability_60         0.946034
# 652        availability_365           availability_eoy         0.888314

# %% [markdown]
# Hotel Room df4

# %%
cuantitativasdf4 = df4.select_dtypes(include=["int64", "float64", "int32", "float32", "int", "float"])
print("Columnas cuantitativas:\n", cuantitativas.columns.tolist())
# Out:
# Columnas cuantitativas:
# ...

# %%
Corr_Factorsdf4=cuantitativasdf4.corr()
Corr_Factorsdf4
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                            0.445397                 NaN
# host_is_superhost                              -0.199588                 NaN
# host_listings_count                            -0.187857                 NaN
# host_total_listings_count                      -0.232018                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.304257                 NaN
# longitude                                      -0.261971                 NaN
# accommodates                                   -0.063696                 NaN
# ...

# %%
Corr_factordf4= abs(Corr_Factorsdf4)
Corr_factordf4
# Out:
#                                               Unnamed: 0  host_response_rate  \
# Unnamed: 0                                      1.000000                 NaN
# host_response_rate                                   NaN                 NaN
# host_acceptance_rate                            0.445397                 NaN
# host_is_superhost                               0.199588                 NaN
# host_listings_count                             0.187857                 NaN
# host_total_listings_count                       0.232018                 NaN
# host_has_profile_pic                                 NaN                 NaN
# host_identity_verified                               NaN                 NaN
# latitude                                        0.304257                 NaN
# longitude                                       0.261971                 NaN
# accommodates                                    0.063696                 NaN
# ...

# %%
pares = [
    ("host_acceptance_rate", "host_response_rate"),
    ("review_scores_rating", "calculated_host_listings_count"),
    ("host_acceptance_rate", "price"),
    ("availability_365", "number_of_reviews"),
    ("host_acceptance_rate", "number_of_reviews"),
    ("reviews_per_month", "review_scores_communication"),
]

for x, y in pares:
    if x in df4.columns and y in df4.columns:
        corr = df4[[x, y]].corr().iloc[0,1]
        print(f"Correlación entre {x} y {y}: {abs(corr):.6f}")
# Out:
# Correlación entre host_acceptance_rate y host_response_rate: nan
# Correlación entre review_scores_rating y calculated_host_listings_count: 0.144723
# Correlación entre host_acceptance_rate y price: 0.359500
# Correlación entre availability_365 y number_of_reviews: 0.297395
# Correlación entre host_acceptance_rate y number_of_reviews: 0.047805
# Correlación entre reviews_per_month y review_scores_communication: 0.188123

# %%
num_df4 = df4.select_dtypes(include=["int64","float64","int32","float32","int","float"])
num_df4 = num_df4.loc[:, ~num_df4.columns.str.contains('^Unnamed')]

corr_df4 = num_df4.corr().abs()

mask = np.triu(np.ones(corr_df4.shape), k=1).astype(bool)
corr_triu_df4 = corr_df4.where(mask)

corr_pairs_df4 = corr_triu_df4.stack().reset_index()
corr_pairs_df4.columns = ["Variable 1", "Variable 2", "Correlación_abs"]

top10_df4 = corr_pairs_df4.sort_values(by="Correlación_abs", ascending=False).head(10)

print("\nTop 10 correlaciones en df4 (Hotel Room):\n")
display(top10_df4)
# Out:
# Top 10 correlaciones en df4 (Hotel Room):
#                  Variable 1                 Variable 2  Correlación_abs
# 386          minimum_nights     minimum_minimum_nights         1.000000
# 687   number_of_reviews_ltm  estimated_occupancy_l365d         1.000000
# 610         availability_60            availability_90         0.988596
# 521  maximum_maximum_nights     maximum_nights_avg_ntm         0.967864
# 497  minimum_maximum_nights     maximum_nights_avg_ntm         0.967314
# 634         availability_90           availability_eoy         0.962778
# 589         availability_30            availability_60         0.955106
# 615         availability_60           availability_eoy         0.938538
# 390          minimum_nights     minimum_nights_avg_ntm         0.930824
# 445  minimum_minimum_nights     minimum_nights_avg_ntm         0.930824
